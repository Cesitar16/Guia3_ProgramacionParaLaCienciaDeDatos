# %%
#Preparación del entorno
import importlib
import sys
import os

sys.path.append(os.path.abspath(".."))

#import pandas y módulo requerido
import pandas as pd
import src.limpieza as limpieza_module
importlib.reload(limpieza_module)
from src.limpieza import limpieza_datos

#lectura de la data (csv)
ruta = "../data/deportistas.csv"
df = pd.read_csv(ruta, encoding = "utf-8")
    
#exploración de la data
print(df.head())
print(df.columns())
print(df.dtypes())

#limpiar y exportar (outputs)
df_limpio = limpiar_datos(df)
df_limpio.head()
df_limpio.to_csv("../outputs/limpio.csv", index=False)
